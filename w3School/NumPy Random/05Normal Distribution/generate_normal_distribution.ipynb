# %% [markdown]
# Random Distribution

# %%
from numpy import random

x=random.normal(size=(2,3))
print(x)
# Out:
# [[ 0.10781623 -1.68101676  1.63572366]
#  [ 0.17071192  1.52991458  0.23513453]]

# %% [markdown]
# Random Distribution with parameter

# %%
from numpy import random

x=random.normal(loc=1,scale=2,size=(2,3))
print(x)
# Out:
# [[ 1.04075977  2.86478428 -0.93098896]
#  [ 2.46471696  0.90301976  4.76968904]]

# %% [markdown]
# Visualization of Random Distribution

# %%
from numpy import random
import matplotlib.pyplot as plt
import seaborn as sns

sns.distplot(random.normal(size=1000),hist=False)
plt.show()
# Out:
# C:\Users\nirob\AppData\Local\Temp\ipykernel_6268\1528955916.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(random.normal(size=1000),hist=False)
