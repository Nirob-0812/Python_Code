# %% [markdown]
# Logistic Distribution

# %%
from numpy import random

x=random.logistic(loc=1,scale=2,size=(2,3))
print(x)
# Out:
# [[ -3.42546622  -5.61817203 -13.80793258]
#  [ -0.32008544   1.20222886   1.58094291]]

# %% [markdown]
# Visualization Logistic Distribution

# %%
import matplotlib.pyplot as plt
import seaborn as sns
from numpy import random

sns.distplot(random.logistic(size=1000),hist=False)
plt.show()
# Out:
# C:\Users\nirob\AppData\Local\Temp\ipykernel_12752\3505138266.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(random.logistic(size=1000),hist=False)

# %% [markdown]
# Diff Between Normal and Logistic Distribution

# %%
from numpy import random 
import seaborn as sns
import matplotlib.pyplot as plt

sns.distplot(random.normal(scale=2,size=1000),hist=False,label='Normal')
sns.distplot(random.logistic(size=1000),hist=False,label='Logistic')
plt.show()
# Out:
# C:\Users\nirob\AppData\Local\Temp\ipykernel_17600\1174960644.py:5: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(random.normal(scale=2,size=1000),hist=False,label='Normal')
# C:\Users\nirob\AppData\Local\Temp\ipykernel_17600\1174960644.py:6: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `kdeplot` (an axes-level function for kernel density plots).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(random.logistic(size=1000),hist=False,label='Logistic')
